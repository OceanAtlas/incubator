# %%
import QC_Library as qc

# %%
file='/Users/oz/downloads/Iceland_all.json'

# %%
retDict_SST_7_20 = qc.outliers.analyze(file, 'sst', gross_range=[-5, 35],verbosity=1)
# Out:
# Starting with gross-range flags array
# /Users/oz/Miniconda/miniconda3/envs/oceanatlas/lib/python3.7/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# /Users/oz/Miniconda/miniconda3/envs/oceanatlas/lib/python3.7/site-packages/QC_Library/outliers.py:56: RuntimeWarning: Mean of empty slice
#   means[indx] = np.nanmean(data[window])
# Starting with 102 flags
# /Users/oz/Miniconda/miniconda3/envs/oceanatlas/lib/python3.7/site-packages/QC_Library/outliers.py:94: RuntimeWarning: invalid value encountered in greater
#   localflags[np.where(np.abs(numDevs) > numStdDevs)] = 4
# 1   107  total points flagged

# %%
qc.outliers.diagnostic_plots(retDict_SST_7_20['parameter'], retDict_SST_7_20['data'], retDict_SST_7_20['times'], 
                xlabel='Time',yrange=[0, 15])

# %%
qc.outliers.diagnostic_plots(retDict_SST_7_20['parameter'], retDict_SST_7_20['data'], retDict_SST_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_SST_7_20['gross_range_flags'],
                'spike_flags' : retDict_SST_7_20['spike_flags']}, yrange=[0, 15], title="SST", ylabel= 'SST', 
                xlabel='Time')

# %%
qc.outliers.diagnostic_plots(retDict_SST_7_20['parameter'], retDict_SST_7_20['data'], retDict_SST_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_SST_7_20['gross_range_flags'],
                'spike_flags' : retDict_SST_7_20['spike_flags']}, yrange=[0, 3], title="SST", ylabel= 'SST', 
                xlabel='Time', time_range=['2014-03-08','2014-05-15'], marker='o')

# %%
retDict_Sal_7_20 = qc.outliers.analyze(file, 'sal', gross_range=[20, 40],verbosity=1)
# Out:
# Starting with gross-range flags array
# Starting with 182 flags
# 1   41  total points flagged by Spike Test
# 2   49  total points flagged by Spike Test
# 3   233  total points flagged

# %%
qc.outliers.diagnostic_plots(retDict_Sal_7_20['parameter'], retDict_Sal_7_20['data'], 
                             retDict_Sal_7_20['times'], xlabel='Time', yrange=[34, 35])

# %%
qc.outliers.diagnostic_plots(retDict_Sal_7_20['parameter'], retDict_Sal_7_20['data'], retDict_Sal_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_Sal_7_20['gross_range_flags'],
                'spike_flags' : retDict_Sal_7_20['spike_flags']}, yrange=[34, 35], title="SSS", 
                ylabel= 'SSS', xlabel='Time')

# %%
retDict_O2_7_20 = qc.outliers.analyze(file, 'sc_o2_umolkg', gross_range=[50, 500], verbosity=1)
# Out:
# Starting with gross-range flags array
# Starting with 101 flags
# 1   112  total points flagged

# %%
qc.outliers.diagnostic_plots(retDict_O2_7_20['parameter'], retDict_O2_7_20['data'], retDict_O2_7_20['times'], 
                yrange=[0, 500], xlabel='Time')

# %%
qc.outliers.diagnostic_plots(retDict_O2_7_20['parameter'], retDict_O2_7_20['data'], retDict_O2_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_O2_7_20['gross_range_flags'],
                'spike_flags' : retDict_O2_7_20['spike_flags']}, yrange=[0, 500], xlabel='Time')

# %%
qc.outliers.diagnostic_plots(retDict_O2_7_20['parameter'], retDict_O2_7_20['data'], retDict_O2_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_O2_7_20['gross_range_flags'],
                'spike_flags' : retDict_O2_7_20['spike_flags']}, yrange=[300, 340], xlabel='Time',
                             time_range=['2013-11-08','2013-11-15'], marker='o')

# %%
qc.outliers.diagnostic_plots(retDict_O2_7_20['parameter'], retDict_O2_7_20['orig_vars'], retDict_O2_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_O2_7_20['gross_range_flags'],
                'spike_flags' : retDict_O2_7_20['spike_flags']}, yrange=[0, 30], xlabel='Time',
                             time_range=['2013-07-01','2014-01-01'], marker='o')

# %%
qc.outliers.diagnostic_plots(retDict_O2_7_20['parameter'], retDict_O2_7_20['variances'], retDict_O2_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_O2_7_20['gross_range_flags'],
                'spike_flags' : retDict_O2_7_20['spike_flags']}, yrange=[0, 30], xlabel='Time',
                             time_range=['2013-07-01','2014-01-01'])

# %%
retDict_Chl_7_20 = qc.outliers.analyze(file, 'chl', gross_range=[0, 50],verbosity=1)
# Out:
# Starting with gross-range flags array
# Starting with 101 flags
# 1   35  total points flagged by Spike Test
# 2   137  total points flagged

# %%
qc.outliers.diagnostic_plots(retDict_Chl_7_20['parameter'], retDict_Chl_7_20['data'], retDict_Chl_7_20['times'], 
                xlabel='Time')

# %%
qc.outliers.diagnostic_plots(retDict_Chl_7_20['parameter'], retDict_Chl_7_20['data'], retDict_Chl_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_Chl_7_20['gross_range_flags'],
                'spike_flags' : retDict_Chl_7_20['spike_flags']}, yrange=[0, 25], xlabel='Time')

# %%
qc.outliers.diagnostic_plots(retDict_Chl_7_20['parameter'], retDict_Chl_7_20['variances'], retDict_Chl_7_20['times'], 
                flag_arrays={'gross_range_flags' : retDict_Chl_7_20['gross_range_flags'],
                'spike_flags' : retDict_Chl_7_20['spike_flags']}, yrange=[0, 10], xlabel='Time',
                             time_range=['2013-07-01','2014-01-01'])
