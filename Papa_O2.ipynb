# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
file = "/Users/oz/Downloads/O2_Downloads/Papa_145W_50N_Jun2009_Jun2010_O2_N2.csv"

# %%
papa_df = pd.read_csv(file, na_values="-999")

# %%
papa_df["O2 umol/kg"].describe()
# Out:
# count    4435.000000
# mean      295.653993
# std        15.977004
# min       259.467200
# 25%       279.630650
# 50%       301.516800
# 75%       307.194150
# max       409.510500
# Name: O2 umol/kg, dtype: float64

# %%
papa_df.columns.values
# Out:
# array(['Mooring Name', 'Latitude', 'Longitude', 'yearday',
#        'Date and Time', 'SST deg C', 'Salinity',
#        'GTD total pressure (mbar)', 'Atm Pressure', 'N2 umol/kg',
#        'O2 umol/kg', 'O2 saturation', 'N2 saturation'], dtype=object)

# %%
type(papa_df['O2 umol/kg'].values)
# Out:
# numpy.ndarray

# %%
file2 = "/Users/oz/Downloads/O2_Downloads/Papa_145W_50N_Jun2011_Apr2012.csv"

# %%
papa_df_m = pd.read_csv(file2, na_values="-999")

# %%
papa_df_m
# Out:
#        Mooring Name  Latitude  Longitude        Date   Time  \
# 0     PAPA_145W_50N    50.122   -144.805  06/12/2011  01:17
# 1     PAPA_145W_50N    50.122   -144.805  06/12/2011  01:47
# 2     PAPA_145W_50N    50.122   -144.805  06/12/2011  02:17
# 3     PAPA_145W_50N    50.122   -144.805  06/12/2011  02:47
# 4     PAPA_145W_50N    50.122   -144.805  06/12/2011  03:17
# 5     PAPA_145W_50N    50.122   -144.805  06/12/2011  03:47
# 6     PAPA_145W_50N    50.122   -144.805  06/12/2011  04:47
# 7     PAPA_145W_50N    50.122   -144.805  06/12/2011  05:17
# 8     PAPA_145W_50N    50.122   -144.805  06/12/2011  05:47
# 9     PAPA_145W_50N    50.122   -144.805  06/12/2011  06:17
# 10    PAPA_145W_50N    50.122   -144.805  06/12/2011  09:17
# 11    PAPA_145W_50N    50.122   -144.805  06/12/2011  12:17
# 12    PAPA_145W_50N    50.122   -144.805  06/12/2011  15:17
# 13    PAPA_145W_50N    50.122   -144.805  06/12/2011  18:17
# 14    PAPA_145W_50N    50.122   -144.805  06/12/2011  21:17
# ...

# %%
papa_df_m["datetime"] = pd.to_datetime(papa_df_m['Date']+ ' ' + papa_df_m['Time'])

# %%
papa_df_m['datetime']
# Out:
# 0      2011-06-12 01:17:00
# 1      2011-06-12 01:47:00
# 2      2011-06-12 02:17:00
# 3      2011-06-12 02:47:00
# 4      2011-06-12 03:17:00
# 5      2011-06-12 03:47:00
# 6      2011-06-12 04:47:00
# 7      2011-06-12 05:17:00
# 8      2011-06-12 05:47:00
# 9      2011-06-12 06:17:00
# 10     2011-06-12 09:17:00
# 11     2011-06-12 12:17:00
# 12     2011-06-12 15:17:00
# 13     2011-06-12 18:17:00
# 14     2011-06-12 21:17:00
# 15     2011-06-13 00:17:00
# 16     2011-06-13 03:17:00
# 17     2011-06-13 06:17:00
# 18     2011-06-13 09:17:00
# 19     2011-06-13 12:17:00
# 20     2011-06-13 15:17:00
# 21     2011-06-13 18:17:00
# 22     2011-06-13 21:17:00
# 23     2011-06-14 00:17:00
# 24     2011-06-14 03:17:00
# 25     2011-06-14 06:17:00
# 26     2011-06-14 09:17:00
# 27     2011-06-14 12:17:00
# 28     2011-06-14 15:17:00
# 29     2011-06-14 18:17:00
#                ...
# 2519   2012-04-22 00:17:00
# 2520   2012-04-22 03:17:00
# 2521   2012-04-22 06:17:00
# ...

# %%
print(papa_df_m.columns.values)
pco2=papa_df_m['pCO2 SW (sat) uatm'].values
datetime=papa_df_m['datetime'].values
# Out:
# ['Mooring Name' 'Latitude' 'Longitude' 'Date' 'Time'
#  'xCO2  SW (wet) (umol/mol)' 'QF' 'H2O (mmol/mol)'
#  'xCO2  Air (wet) (umol/mol)' 'QF.1' 'H2O (mmol/mol).1'
#  'Licor Atm Pressure  (hPa)' 'Licor Temp (C)' '% O2' 'SST (C)' 'Salinity'
#  'xCO2  SW (dry) (umol/mol)' 'xCO2  Air (dry) (umol/mol)'
#  'fCO2  SW (sat) uatm' 'fCO2  Air (sat) uatm' 'dfCO2' 'pCO2 SW (sat) uatm'
#  'pCO2 Air (sat) uatm' 'dpCO2' 'datetime']

# %%
plt.plot(datetime,pco2)

# %%
file_keo = "/Users/oz/Downloads/O2_Downloads/KEO/KEO_145E_32N_Jul2013_Jun2014_O2_N2.csv"

# %%
keouw = pd.read_csv(file_keo, na_values="-999")

# %%
keouw["O2 umol/kg"].describe()
# Out:
# count    2876.000000
# mean      209.747684
# std         5.572332
# min       193.436200
# 25%       205.057625
# 50%       210.504500
# 75%       214.511925
# max       221.856400
# Name: O2 umol/kg, dtype: float64

# %%
file_keo_m = "/Users/oz/Downloads/O2_Downloads/KEO/KEO_145E_32N_Jul2013_Jun2014.csv"

# %%
keom = pd.read_csv(file_keo_m, na_values="-999")

# %%
keom["pCO2 SW (sat) uatm"].describe()
# Out:
# count    2839.000000
# mean      350.269215
# std        26.445378
# min       309.200000
# 25%       329.100000
# 50%       337.400000
# 75%       372.750000
# max       419.600000
# Name: pCO2 SW (sat) uatm, dtype: float64

# %%
keouw
# Out:
#       Mooring Name  Latitude  Longitude   yearday        Date and Time  \
# 0     KEO_145E_32N    32.252    144.561  186.2840  07/05/2013 06:49:01
# 1     KEO_145E_32N    32.252    144.561  186.3049  07/05/2013 07:19:01
# 2     KEO_145E_32N    32.252    144.561  186.3257  07/05/2013 07:49:01
# 3     KEO_145E_32N    32.252    144.561  186.3465  07/05/2013 08:19:01
# 4     KEO_145E_32N    32.252    144.561  186.3674  07/05/2013 08:49:01
# 5     KEO_145E_32N    32.252    144.561  186.3882  07/05/2013 09:19:01
# 6     KEO_145E_32N    32.252    144.561  186.4090  07/05/2013 09:49:01
# 7     KEO_145E_32N    32.252    144.561  186.4299  07/05/2013 10:19:01
# 8     KEO_145E_32N    32.252    144.561  186.5132  07/05/2013 12:19:01
# 9     KEO_145E_32N    32.252    144.561  186.6382  07/05/2013 15:19:01
# 10    KEO_145E_32N    32.252    144.561  186.7632  07/05/2013 18:19:01
# 11    KEO_145E_32N    32.252    144.561  186.8882  07/05/2013 21:19:01
# ...

# %%
keom
# Out:
#       Mooring Name  Latitude  Longitude        Date   Time  \
# 0     KEO_145E_32N    32.252    144.561  07/05/2013  06:47
# 1     KEO_145E_32N    32.252    144.561  07/05/2013  07:17
# 2     KEO_145E_32N    32.252    144.561  07/05/2013  07:47
# 3     KEO_145E_32N    32.252    144.561  07/05/2013  08:17
# 4     KEO_145E_32N    32.252    144.561  07/05/2013  08:47
# 5     KEO_145E_32N    32.252    144.561  07/05/2013  09:17
# 6     KEO_145E_32N    32.252    144.561  07/05/2013  09:47
# 7     KEO_145E_32N    32.252    144.561  07/05/2013  10:17
# 8     KEO_145E_32N    32.252    144.561  07/05/2013  12:17
# 9     KEO_145E_32N    32.252    144.561  07/05/2013  15:17
# 10    KEO_145E_32N    32.252    144.561  07/05/2013  18:17
# 11    KEO_145E_32N    32.252    144.561  07/05/2013  21:17
# 12    KEO_145E_32N    32.252    144.561  07/06/2013  00:17
# 13    KEO_145E_32N    32.252    144.561  07/06/2013  03:17
# 14    KEO_145E_32N    32.252    144.561  07/06/2013  06:17
# ...
